# %%
import pandas as pd
import numpy as np
from pipeline import *
# Out:
# [nltk_data] Downloading package stopwords to /home/peichi/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/peichi/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# /home/peichi/.local/lib/python3.11/site-packages/torch/cuda/__init__.py:716: UserWarning: Can't initialize NVML
#   warnings.warn("Can't initialize NVML")

# %% [markdown]
# ### Use Function Calls to Utilize Search Engine

# %% [markdown]
# **Initializing search engine**

# %%
search_obj = SearchEngine(ranker="VectorRanker", l2r=True)
raw_data = pd.read_csv(POSTINGS_CATEGORY_PATH)
# Out:
# Initializing Search Engine...
#  - Initializing tokenizer
#  - Initializing document indexing
# 123842it [00:00, 3087055.21it/s]
# 123842it [00:02, 47044.31it/s]
# Loading ranker...
# Initializing L2R ranker...
#  - initializing skills scorer...
#  - initializing cross encoder scorer
#  - initializing feature extractor
# Training L2R ranker...
# 100%|██████████| 10/10 [03:10<00:00, 19.07s/it]
# [LightGBM] [Info] Total Bins 1784
# [LightGBM] [Info] Number of data points in the train set: 715, number of used features: 11
# Search Engine initialized!

# %% [markdown]
# **Search with resume text**

# %%
testing_resume_data = pd.read_csv(RESUME_PATH)
query = testing_resume_data.iloc[1]["Clean_Resume"]
results = search_obj.search(query)
printSearchResponse(raw_data, results)
# Out:
# There are a total of 123842 postings found.
# The top 5 search results of your resume is:
#
# 1
# ===
# Job title: Internal Communications Specialist,
# Job description: Our Human Resources Department is focused on ALDI’s most valuable asset: our people. With teams including Administration, Internal Communications, Payroll & Benefits, Human Resource Information Systems, Legal, Risk & Security, Recruitment and Training & Development, HR makes sure that ALDI continues to employ talented and motivated people that are focused on preserving the supportive culture we're known for.
#
# ...

# %% [markdown]
# **Search with resume PDF file**

# %%
results = search_obj.search_pdf("data/resume_sample_IT_10089434.pdf")
printSearchResponse(raw_data, results)
# Out:
# There are a total of 123842 postings found.
# The top 5 search results of your resume is:
#
# 1
# ===
# Job title: Java Software Engineer
# Job description: H4 EAD, GC and USC
#
# Required Qualifications
# • Bachelor’s degree or foreign equivalent from an accredited institution. Will also consider three years of progressive experience in the specialty in lieu of every year of education.
# • At least 2 years of experience in Information Technology.
# • Experience in Java/J2EE technologies in developing J2EE based web application.
#
# Preferred Qualifications
# • At least 2 years of experience in Java/J2EE, web services, SQl.
# • 3 years of experience in design and development of web application using Java/J2EE , Spring framework
# • 2Years of experience in using REST/SOAP/HTTPS web services.
# • 2 Years of experience in SQL/PLSQL.
# • Experience in SCALA will be preferred.
# • Experience in telecommunication domain would be a Plus
# ...

# %%
results = search_obj.search_pdf("data/resume_sample_BUSINESS_DEVELOPMENT_10228751.pdf")
printSearchResponse(raw_data, results)
# Out:
# There are a total of 123842 postings found.
# The top 5 search results of your resume is:
#
# 1
# ===
# Job title: Marketing and Business Development Manager
# ...

# %% [markdown]
# ### Interactive Mode

# %%
interactive(ranker="VectorRanker", l2r=True)
# Out:
# Initializing Search Engine...
#  - Initializing tokenizer
#  - Initializing document indexing
# 123842it [00:00, 3160978.76it/s]
# 123842it [00:02, 46923.08it/s]
# Loading ranker...
# Search Engine initialized!
# --------------
# Choose your mode (pdf/text):  pdf
# Enter your resume file path:  data/resume_sample_IT_10089434.pdf
# There are a total of 123611 postings found.
# The top 5 search results of your resume is:
#
# 1
# ===
# Job title: Senior System Administrator
# Job description: Job Title: Senior System AdministratorLocations: Hybrid Remote on any of the following locations:Washington, DCNew York City, NYLos Angeles, CAEmployment Term: 6 Months ContractIndustry: Radio and Broadcasting ServicesImportant Note: Must have legal authorization to work in the United States. No Corp to Corp (C2C) or Visa sponsorship provided.
# ...
